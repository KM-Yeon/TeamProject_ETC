# %%
# 분석
import pandas as pd
import numpy as np

# 시각화
import seaborn as sns
import matplotlib.pyplot as plt

# ML
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, KFold
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, roc_auc_score,precision_score,recall_score, roc_curve, classification_report,precision_recall_curve
from sklearn.metrics import make_scorer
from xgboost.sklearn import XGBClassifier
from lightgbm import LGBMClassifier
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### 코랩이용시

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
d_path = '/content/drive/MyDrive/Colab Notebooks/Dacon/'
X_train = pd.read_csv(d_path + 'train_features.csv')
y_train = pd.read_csv(d_path + 'train_labels.csv')
X_test = pd.read_csv(d_path + 'test_features.csv')
submission = pd.read_csv(d_path + 'sample_submission.csv')

display(X_train.head(3))
display(y_train.head(3))
display(X_test.head(3))
# Out:
#    id  time     acc_x     acc_y     acc_z      gy_x       gy_y       gy_z
# 0   0     0  1.206087 -0.179371 -0.148447 -0.591608 -30.549010 -31.676112
# 1   0     1  1.287696 -0.198974 -0.182444  0.303100 -39.139103 -24.927216
# 2   0     2  1.304609 -0.195114 -0.253382 -3.617278 -44.122565 -25.019629
#    id  label                 label_desc
# 0   0     37  Shoulder Press (dumbbell)
# 1   1     26               Non-Exercise
# 2   2      3         Biceps Curl (band)
#      id  time     acc_x     acc_y     acc_z       gy_x       gy_y       gy_z
# 0  3125     0 -0.628100 -0.160155  0.151487  49.665357  88.435961  13.597668
# 1  3125     1 -0.462548  0.012462 -0.053726  56.953059  96.185341  16.278458
# 2  3125     2 -0.363481 -0.091789 -0.130004  29.557396  93.836453  13.329043

# %% [markdown]
# ### 쥬피터 이용시

# %%
# X_train = pd.read_csv('train_features.csv')
# y_train = pd.read_csv( 'train_labels.csv')
# X_test = pd.read_csv('test_features.csv')
# submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# ----------------------------

# %% [markdown]
# #### X_train의 데이터를 통해서 id와 time을 제외한 피쳐를 대상으로 id를 기준으로 잡아 합, 평균, 중앙값, 최소값, 최대값을 구함

# %%
X_pivot_train = pd.pivot_table(data = X_train, # X_train의 데이터를 통해서
                               values = X_train.columns[2:],  # id와 time을 제외한 피쳐를 대상으로
                               index = 'id', # id를 기준으로 잡아
                               aggfunc = ['sum','mean',         # 합, 평균
                                          'median','min','max', # 중앙값 최소값, 최대값
                                          'std','var'           # 베셀 보정 표본 표준편차, 비편향 편차 의 값을 구합니다.
                                         ]
                              )

X_pivot_test = pd.pivot_table(data = X_test, 
                               values = X_test.columns[2:], 
                               index = 'id', 
                               aggfunc = ['sum','mean',        
                                          'median','min','max',
                                          'std','var'          
                                         ]
                              )

display(X_pivot_train.head(3))
display(X_pivot_test.head(3))
# Out:
#            sum                          ...          var
#          acc_x       acc_y       acc_z  ...         gy_x          gy_y         gy_z
# id                                      ...
# 0   558.797337 -131.082711 -222.252919  ...   176.470384    590.513292   638.834979
# 1  -459.948117 -190.354639   -2.534051  ...  6279.700472   9217.015511  5707.098884
# 2    23.901616  -49.441742  375.607013  ...   646.325142  14150.683677   193.775778
#
# [3 rows x 42 columns]
#              sum                          ...          var
#            acc_x       acc_y       acc_z  ...         gy_x         gy_y         gy_z
# id                                        ...
# 3125 -611.238360  -11.744605 -139.355669  ...   166.357553  1023.553453   150.102867
# 3126 -313.705824  367.296809  -42.655405  ...  2665.150566  2089.066820  3795.159662
# 3127  304.167948  542.291164  -84.658968  ...   518.511372   181.383940   530.909012
#
# [3 rows x 42 columns]

# %%
X_pivot_train.columns[:5]
# Out:
# MultiIndex([('sum', 'acc_x'),
#             ('sum', 'acc_y'),
#             ('sum', 'acc_z'),
#             ('sum',  'gy_x'),
#             ('sum',  'gy_y')],
#            )

# %%
X_columns = [agg + '_' + column for agg,column in X_pivot_train.columns]
X_pivot_train.columns = X_columns
X_pivot_test.columns = X_columns
display(X_pivot_train.head())
# Out:
#      sum_acc_x   sum_acc_y   sum_acc_z  ...      var_gy_x      var_gy_y     var_gy_z
# id                                      ...
# 0   558.797337 -131.082711 -222.252919  ...    176.470384    590.513292   638.834979
# 1  -459.948117 -190.354639   -2.534051  ...   6279.700472   9217.015511  5707.098884
# 2    23.901616  -49.441742  375.607013  ...    646.325142  14150.683677   193.775778
# 3  -532.621192  -52.600737  136.413976  ...   1842.887012   1365.558625   559.187841
# 4  -395.410844 -202.240064  121.654507  ...  11719.982095   3662.008463  2129.668017
#
# [5 rows x 42 columns]

# %%
X_pivot_train = X_pivot_train.reset_index()
X_pivot_test = X_pivot_test.reset_index()

display(X_pivot_train.head())
display(X_pivot_test.head())
# Out:
#    id   sum_acc_x   sum_acc_y  ...      var_gy_x      var_gy_y     var_gy_z
# 0   0  558.797337 -131.082711  ...    176.470384    590.513292   638.834979
# 1   1 -459.948117 -190.354639  ...   6279.700472   9217.015511  5707.098884
# 2   2   23.901616  -49.441742  ...    646.325142  14150.683677   193.775778
# 3   3 -532.621192  -52.600737  ...   1842.887012   1365.558625   559.187841
# 4   4 -395.410844 -202.240064  ...  11719.982095   3662.008463  2129.668017
#
# [5 rows x 43 columns]
#      id   sum_acc_x   sum_acc_y  ...     var_gy_x     var_gy_y     var_gy_z
# 0  3125 -611.238360  -11.744605  ...   166.357553  1023.553453   150.102867
# 1  3126 -313.705824  367.296809  ...  2665.150566  2089.066820  3795.159662
# 2  3127  304.167948  542.291164  ...   518.511372   181.383940   530.909012
# 3  3128 -346.561617 -366.333946  ...  1833.394532  2031.298793  1441.521366
# 4  3129 -443.184021  109.521180  ...  8519.652350  4611.927587  1879.483194
#
# [5 rows x 43 columns]

# %%
X_pivot_train.shape
# Out:
# (3125, 43)

# %%
ftr = X_pivot_train
target = y_train['label']

# %% [markdown]
# ### LGBM

# %%
X_train, X_val, y_train, y_val = train_test_split(ftr, target, test_size=0.2, random_state=156)

lgbm_wrapper = LGBMClassifier(n_estimators=1000, num_leaves=100, subsample=0.8,
                      min_child_samples=320, max_depth=30)

evals = [(X_val, y_val)]
lgbm_wrapper.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
preds = lgbm_wrapper.predict(X_pivot_test)
pred_proba = lgbm_wrapper.predict_proba(X_pivot_test)[:,:]
# Out:
# [1]	valid_0's multi_logloss: 2.54967	valid_0's multi_logloss: 2.54967
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 2.44754	valid_0's multi_logloss: 2.44754
# [3]	valid_0's multi_logloss: 2.36224	valid_0's multi_logloss: 2.36224
# [4]	valid_0's multi_logloss: 2.28827	valid_0's multi_logloss: 2.28827
# [5]	valid_0's multi_logloss: 2.22081	valid_0's multi_logloss: 2.22081
# [6]	valid_0's multi_logloss: 2.16124	valid_0's multi_logloss: 2.16124
# [7]	valid_0's multi_logloss: 2.10861	valid_0's multi_logloss: 2.10861
# [8]	valid_0's multi_logloss: 2.0579	valid_0's multi_logloss: 2.0579
# [9]	valid_0's multi_logloss: 2.00773	valid_0's multi_logloss: 2.00773
# [10]	valid_0's multi_logloss: 1.96496	valid_0's multi_logloss: 1.96496
# [11]	valid_0's multi_logloss: 1.92285	valid_0's multi_logloss: 1.92285
# [12]	valid_0's multi_logloss: 1.88298	valid_0's multi_logloss: 1.88298
# [13]	valid_0's multi_logloss: 1.84782	valid_0's multi_logloss: 1.84782
# [14]	valid_0's multi_logloss: 1.81528	valid_0's multi_logloss: 1.81528
# [15]	valid_0's multi_logloss: 1.7849	valid_0's multi_logloss: 1.7849
# [16]	valid_0's multi_logloss: 1.74964	valid_0's multi_logloss: 1.74964
# [17]	valid_0's multi_logloss: 1.72307	valid_0's multi_logloss: 1.72307
# [18]	valid_0's multi_logloss: 1.69399	valid_0's multi_logloss: 1.69399
# [19]	valid_0's multi_logloss: 1.66657	valid_0's multi_logloss: 1.66657
# [20]	valid_0's multi_logloss: 1.6378	valid_0's multi_logloss: 1.6378
# [21]	valid_0's multi_logloss: 1.61022	valid_0's multi_logloss: 1.61022
# [22]	valid_0's multi_logloss: 1.58632	valid_0's multi_logloss: 1.58632
# [23]	valid_0's multi_logloss: 1.56451	valid_0's multi_logloss: 1.56451
# [24]	valid_0's multi_logloss: 1.54248	valid_0's multi_logloss: 1.54248
# [25]	valid_0's multi_logloss: 1.5221	valid_0's multi_logloss: 1.5221
# [26]	valid_0's multi_logloss: 1.50271	valid_0's multi_logloss: 1.50271
# [27]	valid_0's multi_logloss: 1.48135	valid_0's multi_logloss: 1.48135
# [28]	valid_0's multi_logloss: 1.46254	valid_0's multi_logloss: 1.46254
# [29]	valid_0's multi_logloss: 1.44014	valid_0's multi_logloss: 1.44014
# [30]	valid_0's multi_logloss: 1.42699	valid_0's multi_logloss: 1.42699
# [31]	valid_0's multi_logloss: 1.40903	valid_0's multi_logloss: 1.40903
# [32]	valid_0's multi_logloss: 1.39176	valid_0's multi_logloss: 1.39176
# [33]	valid_0's multi_logloss: 1.37603	valid_0's multi_logloss: 1.37603
# [34]	valid_0's multi_logloss: 1.36271	valid_0's multi_logloss: 1.36271
# [35]	valid_0's multi_logloss: 1.34856	valid_0's multi_logloss: 1.34856
# [36]	valid_0's multi_logloss: 1.33284	valid_0's multi_logloss: 1.33284
# [37]	valid_0's multi_logloss: 1.31976	valid_0's multi_logloss: 1.31976
# [38]	valid_0's multi_logloss: 1.30735	valid_0's multi_logloss: 1.30735
# [39]	valid_0's multi_logloss: 1.29583	valid_0's multi_logloss: 1.29583
# [40]	valid_0's multi_logloss: 1.28215	valid_0's multi_logloss: 1.28215
# [41]	valid_0's multi_logloss: 1.27067	valid_0's multi_logloss: 1.27067
# [42]	valid_0's multi_logloss: 1.25805	valid_0's multi_logloss: 1.25805
# [43]	valid_0's multi_logloss: 1.24676	valid_0's multi_logloss: 1.24676
# [44]	valid_0's multi_logloss: 1.23453	valid_0's multi_logloss: 1.23453
# [45]	valid_0's multi_logloss: 1.22391	valid_0's multi_logloss: 1.22391
# [46]	valid_0's multi_logloss: 1.21486	valid_0's multi_logloss: 1.21486
# [47]	valid_0's multi_logloss: 1.20366	valid_0's multi_logloss: 1.20366
# [48]	valid_0's multi_logloss: 1.19522	valid_0's multi_logloss: 1.19522
# [49]	valid_0's multi_logloss: 1.18602	valid_0's multi_logloss: 1.18602
# [50]	valid_0's multi_logloss: 1.17581	valid_0's multi_logloss: 1.17581
# [51]	valid_0's multi_logloss: 1.16673	valid_0's multi_logloss: 1.16673
# [52]	valid_0's multi_logloss: 1.15784	valid_0's multi_logloss: 1.15784
# [53]	valid_0's multi_logloss: 1.15111	valid_0's multi_logloss: 1.15111
# [54]	valid_0's multi_logloss: 1.14383	valid_0's multi_logloss: 1.14383
# [55]	valid_0's multi_logloss: 1.13564	valid_0's multi_logloss: 1.13564
# [56]	valid_0's multi_logloss: 1.12888	valid_0's multi_logloss: 1.12888
# [57]	valid_0's multi_logloss: 1.12103	valid_0's multi_logloss: 1.12103
# [58]	valid_0's multi_logloss: 1.11262	valid_0's multi_logloss: 1.11262
# [59]	valid_0's multi_logloss: 1.10572	valid_0's multi_logloss: 1.10572
# [60]	valid_0's multi_logloss: 1.1007	valid_0's multi_logloss: 1.1007
# [61]	valid_0's multi_logloss: 1.09455	valid_0's multi_logloss: 1.09455
# [62]	valid_0's multi_logloss: 1.08812	valid_0's multi_logloss: 1.08812
# [63]	valid_0's multi_logloss: 1.08245	valid_0's multi_logloss: 1.08245
# [64]	valid_0's multi_logloss: 1.07756	valid_0's multi_logloss: 1.07756
# [65]	valid_0's multi_logloss: 1.0729	valid_0's multi_logloss: 1.0729
# [66]	valid_0's multi_logloss: 1.06775	valid_0's multi_logloss: 1.06775
# [67]	valid_0's multi_logloss: 1.06198	valid_0's multi_logloss: 1.06198
# [68]	valid_0's multi_logloss: 1.05822	valid_0's multi_logloss: 1.05822
# [69]	valid_0's multi_logloss: 1.05378	valid_0's multi_logloss: 1.05378
# [70]	valid_0's multi_logloss: 1.04827	valid_0's multi_logloss: 1.04827
# [71]	valid_0's multi_logloss: 1.04262	valid_0's multi_logloss: 1.04262
# [72]	valid_0's multi_logloss: 1.03976	valid_0's multi_logloss: 1.03976
# [73]	valid_0's multi_logloss: 1.03594	valid_0's multi_logloss: 1.03594
# [74]	valid_0's multi_logloss: 1.03051	valid_0's multi_logloss: 1.03051
# [75]	valid_0's multi_logloss: 1.02632	valid_0's multi_logloss: 1.02632
# [113]	valid_0's multi_logloss: 0.965434	valid_0's multi_logloss: 0.965434
# [114]	valid_0's multi_logloss: 0.966266	valid_0's multi_logloss: 0.966266
# [115]	valid_0's multi_logloss: 0.967185	valid_0's multi_logloss: 0.967185
# [116]	valid_0's multi_logloss: 0.9688	valid_0's multi_logloss: 0.9688
# [117]	valid_0's multi_logloss: 0.967503	valid_0's multi_logloss: 0.967503
# [118]	valid_0's multi_logloss: 0.967405	valid_0's multi_logloss: 0.967405
# [119]	valid_0's multi_logloss: 0.967307	valid_0's multi_logloss: 0.967307
# [120]	valid_0's multi_logloss: 0.967074	valid_0's multi_logloss: 0.967074
# [121]	valid_0's multi_logloss: 0.965506	valid_0's multi_logloss: 0.965506
# [122]	valid_0's multi_logloss: 0.965944	valid_0's multi_logloss: 0.965944
# [123]	valid_0's multi_logloss: 0.965724	valid_0's multi_logloss: 0.965724
# [124]	valid_0's multi_logloss: 0.965148	valid_0's multi_logloss: 0.965148
# [125]	valid_0's multi_logloss: 0.964324	valid_0's multi_logloss: 0.964324
# [126]	valid_0's multi_logloss: 0.964763	valid_0's multi_logloss: 0.964763
# [127]	valid_0's multi_logloss: 0.963924	valid_0's multi_logloss: 0.963924
# [128]	valid_0's multi_logloss: 0.963473	valid_0's multi_logloss: 0.963473
# [129]	valid_0's multi_logloss: 0.964156	valid_0's multi_logloss: 0.964156
# [130]	valid_0's multi_logloss: 0.963034	valid_0's multi_logloss: 0.963034
# [131]	valid_0's multi_logloss: 0.962912	valid_0's multi_logloss: 0.962912
# [132]	valid_0's multi_logloss: 0.963537	valid_0's multi_logloss: 0.963537
# [133]	valid_0's multi_logloss: 0.963192	valid_0's multi_logloss: 0.963192
# [134]	valid_0's multi_logloss: 0.962893	valid_0's multi_logloss: 0.962893
# [135]	valid_0's multi_logloss: 0.963725	valid_0's multi_logloss: 0.963725
# [136]	valid_0's multi_logloss: 0.963652	valid_0's multi_logloss: 0.963652
# [137]	valid_0's multi_logloss: 0.96313	valid_0's multi_logloss: 0.96313
# [138]	valid_0's multi_logloss: 0.964062	valid_0's multi_logloss: 0.964062
# [139]	valid_0's multi_logloss: 0.963734	valid_0's multi_logloss: 0.963734
# [140]	valid_0's multi_logloss: 0.964793	valid_0's multi_logloss: 0.964793
# [141]	valid_0's multi_logloss: 0.965015	valid_0's multi_logloss: 0.965015
# [142]	valid_0's multi_logloss: 0.964592	valid_0's multi_logloss: 0.964592
# [143]	valid_0's multi_logloss: 0.96443	valid_0's multi_logloss: 0.96443
# [144]	valid_0's multi_logloss: 0.966142	valid_0's multi_logloss: 0.966142
# [145]	valid_0's multi_logloss: 0.966605	valid_0's multi_logloss: 0.966605
# [146]	valid_0's multi_logloss: 0.966669	valid_0's multi_logloss: 0.966669
# [147]	valid_0's multi_logloss: 0.967056	valid_0's multi_logloss: 0.967056
# [148]	valid_0's multi_logloss: 0.968562	valid_0's multi_logloss: 0.968562
# [149]	valid_0's multi_logloss: 0.968473	valid_0's multi_logloss: 0.968473
# [223]	valid_0's multi_logloss: 1.0359	valid_0's multi_logloss: 1.0359
# [224]	valid_0's multi_logloss: 1.03796	valid_0's multi_logloss: 1.03796
# [225]	valid_0's multi_logloss: 1.03968	valid_0's multi_logloss: 1.03968
# [226]	valid_0's multi_logloss: 1.04003	valid_0's multi_logloss: 1.04003
# [227]	valid_0's multi_logloss: 1.04148	valid_0's multi_logloss: 1.04148
# [228]	valid_0's multi_logloss: 1.04336	valid_0's multi_logloss: 1.04336
# [229]	valid_0's multi_logloss: 1.04549	valid_0's multi_logloss: 1.04549
# [230]	valid_0's multi_logloss: 1.04657	valid_0's multi_logloss: 1.04657
# [231]	valid_0's multi_logloss: 1.04731	valid_0's multi_logloss: 1.04731
# [232]	valid_0's multi_logloss: 1.04935	valid_0's multi_logloss: 1.04935
# [233]	valid_0's multi_logloss: 1.05098	valid_0's multi_logloss: 1.05098
# [234]	valid_0's multi_logloss: 1.05302	valid_0's multi_logloss: 1.05302
# Early stopping, best iteration is:
# [134]	valid_0's multi_logloss: 0.962893	valid_0's multi_logloss: 0.962893

# %%
print(pred_proba.shape)
# Out:
# (782, 61)

# %% [markdown]
# # 앙상블 Voting을 위한 작업

# %% [markdown]
# ---------------------------------------
# ### RandomForest 최적 Parameter 찾기

# %%
def SCORES(y_val, pred, proba) :
    #acc = accuracy_score(y_val, pred)
    f1 = f1_score(y_val, pred, average='macro')
    #print(y_val[:10])
    #print(proba[:10])
    auc = roc_auc_score(y_val, proba, average='macro', multi_class='ovo')

# %%
print(y_val.shape)
print(pred_proba.shape)
print(preds.shape)
# Out:
# (625,)
# (782, 61)
# (782,)

# %%
rf_model = RandomForestClassifier(n_jobs=-1, random_state=0, min_samples_leaf=30)

# %%
# 수정 필요
my_hyper_param = {
    "n_estimators"      :[700,800], # 700 
    "max_depth"         :[15,17,19],  # 17
    "min_samples_leaf"  :[1,3]  # 1
}

# %%
from sklearn.metrics import make_scorer

gcv_model = GridSearchCV(rf_model, param_grid=my_hyper_param, scoring='roc_auc_ovr', refit=True, cv=5, verbose=0)
#scoring=make_scorer(recall_score, average='micro')

gcv_model.fit(X_train, y_train)

print("best_estimator:", gcv_model.best_estimator_)
print("best_params:",    gcv_model.best_params_)
print("best_score:" ,    gcv_model.best_score_)

# %% [markdown]
# ### RandomForest 학습

# %%
rfc = rf_model = RandomForestClassifier(n_jobs=-1, random_state=0, min_samples_leaf=1, n_estimators=700, max_depth=17)
rfc.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=17, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=700,
#                        n_jobs=-1, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %% [markdown]
# ### XGBOOST 최적 Parameter 찾기

# %%
estimator = XGBClassifier()
 
parameters = {
              'objective':['binary:logistic'],
              'learning_rate': [0.05, 0.1], #so called `eta` value 0.05
              'max_depth': [6,8,10],    # 8
              'n_estimators': [300,350,400],    # 350 
              'seed': [1337]}

clf = GridSearchCV(estimator, parameters, n_jobs=5, 
                   cv=5, 
                   scoring='roc_auc_ovr',
                   verbose=2, refit=True)
 
clf.fit(X_train, y_train)
print('Best parameters found by grid search are:', clf.best_params_)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  31 tasks      | elapsed: 38.1min
# [Parallel(n_jobs=5)]: Done  90 out of  90 | elapsed: 85.0min finished
# Best parameters found by grid search are: {'learning_rate': 0.05, 'max_depth': 8, 'n_estimators': 350, 'objective': 'binary:logistic', 'seed': 1337}

# %% [markdown]
# ### XGBOOST 모델

# %%
estimator = XGBClassifier()
xgb = XGBClassifier(colsample_bytree= 0.7, learning_rate= 0.05, max_depth= 8, min_child_weight= 11, missing= -999, n_estimators= 350, nthread= 4, objective= 'binary:logistic', seed= 1337, silent= 1, subsample= 0.8)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.7, gamma=0,
#               learning_rate=0.05, max_delta_step=0, max_depth=8,
#               min_child_weight=11, missing=-999, n_estimators=350, n_jobs=1,
#               nthread=4, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=1337,
#               silent=1, subsample=0.8, verbosity=1)

# %% [markdown]
# ### LGBM 최적 Parameter 찾기

# %%
estimator = LGBMClassifier(num_leaves=2)
param_grid = {
    'learning_rate': [0.1, 0.05, 0.5],
    'n_estimators': [1100]    # 1100 이상 확인 필요
}

grid = GridSearchCV(estimator, param_grid, cv=5, scoring='roc_auc_ovr')

grid.fit(X_train, y_train)

print('Best parameters found by grid search are:', grid.best_params_)
# Out:
# Best parameters found by grid search are: {'learning_rate': 0.05, 'n_estimators': 1100}

# %% [markdown]
# ### LGBM 모델

# %%
lgb = LGBMClassifier(n_estimators=1100, num_leaves=100, subsample=0.8,
                      min_child_samples=320, max_depth=30, learning_rate=0.05)

evals = [(X_val, y_val)]
lgb.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
# Out:
# [1]	valid_0's multi_logloss: 2.61664	valid_0's multi_logloss: 2.61664
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's multi_logloss: 2.55726	valid_0's multi_logloss: 2.55726
# [3]	valid_0's multi_logloss: 2.5044	valid_0's multi_logloss: 2.5044
# [4]	valid_0's multi_logloss: 2.45795	valid_0's multi_logloss: 2.45795
# [5]	valid_0's multi_logloss: 2.41546	valid_0's multi_logloss: 2.41546
# [6]	valid_0's multi_logloss: 2.37265	valid_0's multi_logloss: 2.37265
# [7]	valid_0's multi_logloss: 2.3345	valid_0's multi_logloss: 2.3345
# [8]	valid_0's multi_logloss: 2.29874	valid_0's multi_logloss: 2.29874
# [9]	valid_0's multi_logloss: 2.26618	valid_0's multi_logloss: 2.26618
# [10]	valid_0's multi_logloss: 2.23554	valid_0's multi_logloss: 2.23554
# [11]	valid_0's multi_logloss: 2.20524	valid_0's multi_logloss: 2.20524
# [12]	valid_0's multi_logloss: 2.17574	valid_0's multi_logloss: 2.17574
# [13]	valid_0's multi_logloss: 2.14794	valid_0's multi_logloss: 2.14794
# [14]	valid_0's multi_logloss: 2.12033	valid_0's multi_logloss: 2.12033
# [15]	valid_0's multi_logloss: 2.09509	valid_0's multi_logloss: 2.09509
# [16]	valid_0's multi_logloss: 2.0704	valid_0's multi_logloss: 2.0704
# [17]	valid_0's multi_logloss: 2.04765	valid_0's multi_logloss: 2.04765
# [18]	valid_0's multi_logloss: 2.02428	valid_0's multi_logloss: 2.02428
# [19]	valid_0's multi_logloss: 2.00001	valid_0's multi_logloss: 2.00001
# [20]	valid_0's multi_logloss: 1.97873	valid_0's multi_logloss: 1.97873
# [21]	valid_0's multi_logloss: 1.95724	valid_0's multi_logloss: 1.95724
# [22]	valid_0's multi_logloss: 1.93689	valid_0's multi_logloss: 1.93689
# [23]	valid_0's multi_logloss: 1.91694	valid_0's multi_logloss: 1.91694
# [24]	valid_0's multi_logloss: 1.89813	valid_0's multi_logloss: 1.89813
# [25]	valid_0's multi_logloss: 1.87914	valid_0's multi_logloss: 1.87914
# [26]	valid_0's multi_logloss: 1.86171	valid_0's multi_logloss: 1.86171
# [27]	valid_0's multi_logloss: 1.84508	valid_0's multi_logloss: 1.84508
# [28]	valid_0's multi_logloss: 1.82689	valid_0's multi_logloss: 1.82689
# [29]	valid_0's multi_logloss: 1.81055	valid_0's multi_logloss: 1.81055
# [30]	valid_0's multi_logloss: 1.79372	valid_0's multi_logloss: 1.79372
# [31]	valid_0's multi_logloss: 1.77841	valid_0's multi_logloss: 1.77841
# [32]	valid_0's multi_logloss: 1.76348	valid_0's multi_logloss: 1.76348
# [33]	valid_0's multi_logloss: 1.74782	valid_0's multi_logloss: 1.74782
# [34]	valid_0's multi_logloss: 1.73431	valid_0's multi_logloss: 1.73431
# [35]	valid_0's multi_logloss: 1.71994	valid_0's multi_logloss: 1.71994
# [36]	valid_0's multi_logloss: 1.70614	valid_0's multi_logloss: 1.70614
# [37]	valid_0's multi_logloss: 1.69201	valid_0's multi_logloss: 1.69201
# [38]	valid_0's multi_logloss: 1.67728	valid_0's multi_logloss: 1.67728
# [39]	valid_0's multi_logloss: 1.66319	valid_0's multi_logloss: 1.66319
# [40]	valid_0's multi_logloss: 1.65004	valid_0's multi_logloss: 1.65004
# [41]	valid_0's multi_logloss: 1.63728	valid_0's multi_logloss: 1.63728
# [42]	valid_0's multi_logloss: 1.62497	valid_0's multi_logloss: 1.62497
# [43]	valid_0's multi_logloss: 1.61126	valid_0's multi_logloss: 1.61126
# [44]	valid_0's multi_logloss: 1.60003	valid_0's multi_logloss: 1.60003
# [45]	valid_0's multi_logloss: 1.58808	valid_0's multi_logloss: 1.58808
# [46]	valid_0's multi_logloss: 1.57722	valid_0's multi_logloss: 1.57722
# [47]	valid_0's multi_logloss: 1.56585	valid_0's multi_logloss: 1.56585
# [48]	valid_0's multi_logloss: 1.55421	valid_0's multi_logloss: 1.55421
# [49]	valid_0's multi_logloss: 1.54493	valid_0's multi_logloss: 1.54493
# [50]	valid_0's multi_logloss: 1.53512	valid_0's multi_logloss: 1.53512
# [51]	valid_0's multi_logloss: 1.52352	valid_0's multi_logloss: 1.52352
# [52]	valid_0's multi_logloss: 1.51422	valid_0's multi_logloss: 1.51422
# [53]	valid_0's multi_logloss: 1.5034	valid_0's multi_logloss: 1.5034
# [54]	valid_0's multi_logloss: 1.4931	valid_0's multi_logloss: 1.4931
# [55]	valid_0's multi_logloss: 1.48314	valid_0's multi_logloss: 1.48314
# [56]	valid_0's multi_logloss: 1.47246	valid_0's multi_logloss: 1.47246
# [57]	valid_0's multi_logloss: 1.46492	valid_0's multi_logloss: 1.46492
# [94]	valid_0's multi_logloss: 1.21224	valid_0's multi_logloss: 1.21224
# [95]	valid_0's multi_logloss: 1.20673	valid_0's multi_logloss: 1.20673
# [96]	valid_0's multi_logloss: 1.20256	valid_0's multi_logloss: 1.20256
# [97]	valid_0's multi_logloss: 1.19732	valid_0's multi_logloss: 1.19732
# [98]	valid_0's multi_logloss: 1.19274	valid_0's multi_logloss: 1.19274
# [99]	valid_0's multi_logloss: 1.18732	valid_0's multi_logloss: 1.18732
# [100]	valid_0's multi_logloss: 1.18329	valid_0's multi_logloss: 1.18329
# [101]	valid_0's multi_logloss: 1.1788	valid_0's multi_logloss: 1.1788
# [102]	valid_0's multi_logloss: 1.17414	valid_0's multi_logloss: 1.17414
# [103]	valid_0's multi_logloss: 1.17041	valid_0's multi_logloss: 1.17041
# [104]	valid_0's multi_logloss: 1.16588	valid_0's multi_logloss: 1.16588
# [105]	valid_0's multi_logloss: 1.16152	valid_0's multi_logloss: 1.16152
# [106]	valid_0's multi_logloss: 1.1575	valid_0's multi_logloss: 1.1575
# [107]	valid_0's multi_logloss: 1.15344	valid_0's multi_logloss: 1.15344
# [108]	valid_0's multi_logloss: 1.14989	valid_0's multi_logloss: 1.14989
# [109]	valid_0's multi_logloss: 1.14584	valid_0's multi_logloss: 1.14584
# [110]	valid_0's multi_logloss: 1.14214	valid_0's multi_logloss: 1.14214
# [111]	valid_0's multi_logloss: 1.13908	valid_0's multi_logloss: 1.13908
# [112]	valid_0's multi_logloss: 1.13551	valid_0's multi_logloss: 1.13551
# [113]	valid_0's multi_logloss: 1.13161	valid_0's multi_logloss: 1.13161
# [114]	valid_0's multi_logloss: 1.12768	valid_0's multi_logloss: 1.12768
# [115]	valid_0's multi_logloss: 1.12391	valid_0's multi_logloss: 1.12391
# [116]	valid_0's multi_logloss: 1.12046	valid_0's multi_logloss: 1.12046
# [117]	valid_0's multi_logloss: 1.11734	valid_0's multi_logloss: 1.11734
# [118]	valid_0's multi_logloss: 1.11446	valid_0's multi_logloss: 1.11446
# [119]	valid_0's multi_logloss: 1.1109	valid_0's multi_logloss: 1.1109
# [120]	valid_0's multi_logloss: 1.10717	valid_0's multi_logloss: 1.10717
# [121]	valid_0's multi_logloss: 1.10348	valid_0's multi_logloss: 1.10348
# [122]	valid_0's multi_logloss: 1.10044	valid_0's multi_logloss: 1.10044
# [123]	valid_0's multi_logloss: 1.09744	valid_0's multi_logloss: 1.09744
# [124]	valid_0's multi_logloss: 1.09444	valid_0's multi_logloss: 1.09444
# [125]	valid_0's multi_logloss: 1.09102	valid_0's multi_logloss: 1.09102
# [126]	valid_0's multi_logloss: 1.08794	valid_0's multi_logloss: 1.08794
# [127]	valid_0's multi_logloss: 1.08607	valid_0's multi_logloss: 1.08607
# [128]	valid_0's multi_logloss: 1.08357	valid_0's multi_logloss: 1.08357
# [129]	valid_0's multi_logloss: 1.08041	valid_0's multi_logloss: 1.08041
# [130]	valid_0's multi_logloss: 1.07717	valid_0's multi_logloss: 1.07717
# [131]	valid_0's multi_logloss: 1.07524	valid_0's multi_logloss: 1.07524
# [132]	valid_0's multi_logloss: 1.07282	valid_0's multi_logloss: 1.07282
# [133]	valid_0's multi_logloss: 1.06997	valid_0's multi_logloss: 1.06997
# [134]	valid_0's multi_logloss: 1.0672	valid_0's multi_logloss: 1.0672
# [135]	valid_0's multi_logloss: 1.06526	valid_0's multi_logloss: 1.06526
# [136]	valid_0's multi_logloss: 1.06315	valid_0's multi_logloss: 1.06315
# [137]	valid_0's multi_logloss: 1.06092	valid_0's multi_logloss: 1.06092
# [138]	valid_0's multi_logloss: 1.05853	valid_0's multi_logloss: 1.05853
# [139]	valid_0's multi_logloss: 1.05612	valid_0's multi_logloss: 1.05612
# [140]	valid_0's multi_logloss: 1.0544	valid_0's multi_logloss: 1.0544
# [141]	valid_0's multi_logloss: 1.0525	valid_0's multi_logloss: 1.0525
# [142]	valid_0's multi_logloss: 1.05084	valid_0's multi_logloss: 1.05084
# [143]	valid_0's multi_logloss: 1.04865	valid_0's multi_logloss: 1.04865
# [144]	valid_0's multi_logloss: 1.04637	valid_0's multi_logloss: 1.04637
# [145]	valid_0's multi_logloss: 1.04399	valid_0's multi_logloss: 1.04399
# [146]	valid_0's multi_logloss: 1.04232	valid_0's multi_logloss: 1.04232
# [147]	valid_0's multi_logloss: 1.03985	valid_0's multi_logloss: 1.03985
# [148]	valid_0's multi_logloss: 1.03786	valid_0's multi_logloss: 1.03786
# [149]	valid_0's multi_logloss: 1.0359	valid_0's multi_logloss: 1.0359
# [150]	valid_0's multi_logloss: 1.03463	valid_0's multi_logloss: 1.03463
# [151]	valid_0's multi_logloss: 1.0323	valid_0's multi_logloss: 1.0323
# [152]	valid_0's multi_logloss: 1.03079	valid_0's multi_logloss: 1.03079
# [153]	valid_0's multi_logloss: 1.02886	valid_0's multi_logloss: 1.02886
# [154]	valid_0's multi_logloss: 1.02657	valid_0's multi_logloss: 1.02657
# [155]	valid_0's multi_logloss: 1.02522	valid_0's multi_logloss: 1.02522
# [156]	valid_0's multi_logloss: 1.02368	valid_0's multi_logloss: 1.02368
# [157]	valid_0's multi_logloss: 1.02167	valid_0's multi_logloss: 1.02167
# [158]	valid_0's multi_logloss: 1.02042	valid_0's multi_logloss: 1.02042
# [159]	valid_0's multi_logloss: 1.01829	valid_0's multi_logloss: 1.01829
# [160]	valid_0's multi_logloss: 1.01721	valid_0's multi_logloss: 1.01721
# [161]	valid_0's multi_logloss: 1.01598	valid_0's multi_logloss: 1.01598
# [162]	valid_0's multi_logloss: 1.0147	valid_0's multi_logloss: 1.0147
# [163]	valid_0's multi_logloss: 1.01384	valid_0's multi_logloss: 1.01384
# [164]	valid_0's multi_logloss: 1.01279	valid_0's multi_logloss: 1.01279
# [165]	valid_0's multi_logloss: 1.0111	valid_0's multi_logloss: 1.0111
# [166]	valid_0's multi_logloss: 1.01015	valid_0's multi_logloss: 1.01015
# [167]	valid_0's multi_logloss: 1.00895	valid_0's multi_logloss: 1.00895
# [315]	valid_0's multi_logloss: 0.974634	valid_0's multi_logloss: 0.974634
# [316]	valid_0's multi_logloss: 0.97504	valid_0's multi_logloss: 0.97504
# [317]	valid_0's multi_logloss: 0.975503	valid_0's multi_logloss: 0.975503
# [318]	valid_0's multi_logloss: 0.975989	valid_0's multi_logloss: 0.975989
# [319]	valid_0's multi_logloss: 0.976458	valid_0's multi_logloss: 0.976458
# [320]	valid_0's multi_logloss: 0.976822	valid_0's multi_logloss: 0.976822
# [321]	valid_0's multi_logloss: 0.9768	valid_0's multi_logloss: 0.9768
# [322]	valid_0's multi_logloss: 0.977483	valid_0's multi_logloss: 0.977483
# [323]	valid_0's multi_logloss: 0.977412	valid_0's multi_logloss: 0.977412
# [324]	valid_0's multi_logloss: 0.977427	valid_0's multi_logloss: 0.977427
# [325]	valid_0's multi_logloss: 0.9774	valid_0's multi_logloss: 0.9774
# [326]	valid_0's multi_logloss: 0.977274	valid_0's multi_logloss: 0.977274
# [327]	valid_0's multi_logloss: 0.977541	valid_0's multi_logloss: 0.977541
# [328]	valid_0's multi_logloss: 0.977542	valid_0's multi_logloss: 0.977542
# [329]	valid_0's multi_logloss: 0.977812	valid_0's multi_logloss: 0.977812
# [330]	valid_0's multi_logloss: 0.97822	valid_0's multi_logloss: 0.97822
# [331]	valid_0's multi_logloss: 0.978937	valid_0's multi_logloss: 0.978937
# [332]	valid_0's multi_logloss: 0.979707	valid_0's multi_logloss: 0.979707
# [333]	valid_0's multi_logloss: 0.980126	valid_0's multi_logloss: 0.980126
# [334]	valid_0's multi_logloss: 0.980776	valid_0's multi_logloss: 0.980776
# [335]	valid_0's multi_logloss: 0.980961	valid_0's multi_logloss: 0.980961
# [336]	valid_0's multi_logloss: 0.981796	valid_0's multi_logloss: 0.981796
# [337]	valid_0's multi_logloss: 0.982093	valid_0's multi_logloss: 0.982093
# [338]	valid_0's multi_logloss: 0.982733	valid_0's multi_logloss: 0.982733
# [339]	valid_0's multi_logloss: 0.9832	valid_0's multi_logloss: 0.9832
# [340]	valid_0's multi_logloss: 0.982979	valid_0's multi_logloss: 0.982979
# [341]	valid_0's multi_logloss: 0.983313	valid_0's multi_logloss: 0.983313
# [342]	valid_0's multi_logloss: 0.983415	valid_0's multi_logloss: 0.983415
# [343]	valid_0's multi_logloss: 0.983267	valid_0's multi_logloss: 0.983267
# [344]	valid_0's multi_logloss: 0.983652	valid_0's multi_logloss: 0.983652
# [345]	valid_0's multi_logloss: 0.983697	valid_0's multi_logloss: 0.983697
# [346]	valid_0's multi_logloss: 0.984149	valid_0's multi_logloss: 0.984149
# [347]	valid_0's multi_logloss: 0.984379	valid_0's multi_logloss: 0.984379
# [348]	valid_0's multi_logloss: 0.98501	valid_0's multi_logloss: 0.98501
# [349]	valid_0's multi_logloss: 0.985829	valid_0's multi_logloss: 0.985829
# [350]	valid_0's multi_logloss: 0.986353	valid_0's multi_logloss: 0.986353
# [351]	valid_0's multi_logloss: 0.9863	valid_0's multi_logloss: 0.9863
# [352]	valid_0's multi_logloss: 0.986529	valid_0's multi_logloss: 0.986529
# [353]	valid_0's multi_logloss: 0.986357	valid_0's multi_logloss: 0.986357
# [354]	valid_0's multi_logloss: 0.987215	valid_0's multi_logloss: 0.987215
# [355]	valid_0's multi_logloss: 0.987783	valid_0's multi_logloss: 0.987783
# [356]	valid_0's multi_logloss: 0.988481	valid_0's multi_logloss: 0.988481
# [357]	valid_0's multi_logloss: 0.988613	valid_0's multi_logloss: 0.988613
# [358]	valid_0's multi_logloss: 0.989196	valid_0's multi_logloss: 0.989196
# [359]	valid_0's multi_logloss: 0.989709	valid_0's multi_logloss: 0.989709
# [360]	valid_0's multi_logloss: 0.990202	valid_0's multi_logloss: 0.990202
# [361]	valid_0's multi_logloss: 0.990641	valid_0's multi_logloss: 0.990641
# [362]	valid_0's multi_logloss: 0.991315	valid_0's multi_logloss: 0.991315
# [363]	valid_0's multi_logloss: 0.991697	valid_0's multi_logloss: 0.991697
# [364]	valid_0's multi_logloss: 0.992355	valid_0's multi_logloss: 0.992355
# [365]	valid_0's multi_logloss: 0.993392	valid_0's multi_logloss: 0.993392
# Early stopping, best iteration is:
# [265]	valid_0's multi_logloss: 0.967199	valid_0's multi_logloss: 0.967199
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.05, max_depth=30,
#                min_child_samples=320, min_child_weight=0.001,
#                min_split_gain=0.0, n_estimators=1100, n_jobs=-1, num_leaves=100,
#                objective=None, random_state=None, reg_alpha=0.0, reg_lambda=0.0,
#                silent=True, subsample=0.8, subsample_for_bin=200000,
#                subsample_freq=0)

# %% [markdown]
# ### 앙상블 Voting

# %%
from sklearn.ensemble import VotingClassifier
eclf = VotingClassifier(estimators=[('rfc', rfc), ('lgb', lgb), ('xgb', xgb)], voting='soft')
eclf.fit(X_train, y_train)
y_prob=eclf.predict_proba(X_pivot_test)

# %%
y_prob.shape
# Out:
# (782, 61)

# %%
submission.iloc[:,1:] = y_prob
submission
# Out:
#        id         0         1         2  ...        57        58        59        60
# 0    3125  0.002890  0.000681  0.001625  ...  0.005749  0.057855  0.000660  0.005047
# 1    3126  0.002137  0.000135  0.000243  ...  0.002867  0.000268  0.000087  0.007212
# 2    3127  0.005744  0.092245  0.001083  ...  0.000944  0.001966  0.060074  0.014422
# 3    3128  0.002771  0.000202  0.003630  ...  0.003066  0.000093  0.000128  0.008539
# 4    3129  0.005591  0.000117  0.000068  ...  0.000884  0.000076  0.000068  0.005944
# ..    ...       ...       ...       ...  ...       ...       ...       ...       ...
# 777  3902  0.009867  0.000187  0.000084  ...  0.004029  0.000165  0.000656  0.003727
# 778  3903  0.002645  0.000237  0.000120  ...  0.001204  0.000068  0.000157  0.007018
# 779  3904  0.001322  0.000106  0.000077  ...  0.000943  0.000079  0.000038  0.007390
# 780  3905  0.001847  0.012293  0.000531  ...  0.000189  0.000228  0.003758  0.000681
# 781  3906  0.001038  0.000168  0.000072  ...  0.001491  0.000233  0.000033  0.006098
#
# [782 rows x 62 columns]

# %%
submission.to_csv(d_path + 'baseline_rff.csv', index=False)
